# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('movies.csv')

# %%
def filter_and_save_csv(file_path, output_path='dest_csv.csv'):
    try:
        # Step 1: Read the CSV file
        df = pd.read_csv('movies.csv')
        
        # Step 2: Filter movies before 2000 with score >= 7
        filtered_df = df[(df['year'] < 2000) & (df['score'] >= 7)]
        
        # Step 3: Save the filtered DataFrame to a new CSV file
        filtered_df.to_csv(output_path, index=False)
        
        print(f"Filtered CSV file saved as '{output_path}'")
        return filtered_df
    
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Use your specific file path
file_path = r'C:\Users\franc\OneDrive\Desktop\Big Data\New folder\movies.csv'
output_path = r'C:\Users\franc\OneDrive\Desktop\Big Data\New folder\dest_csv.csv'

# Call the function
filter_and_save_csv(file_path, output_path)
# Out:
# Filtered CSV file saved as 'C:\Users\franc\OneDrive\Desktop\Big Data\New folder\dest_csv.csv'
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# 6                                 The Blues Brothers          R     Action
# ...                                              ...        ...        ...
# 3628                                           Trick          R     Comedy
# 3629                          A Room for Romeo Brass          R     Comedy
# 3630                               An Affair of Love          R      Drama
# 3632                                  Aimee & Jaguar  Not Rated  Biography
# 3641                            La fille sur le pont          R     Comedy
#
#       year                           released  score      votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000.0
# 2     1980      June 20, 1980 (United States)    8.7  1200000.0
# 3     1980       July 2, 1980 (United States)    7.7   221000.0
# 4     1980      July 25, 1980 (United States)    7.3   108000.0
# 6     1980      June 20, 1980 (United States)    7.9   188000.0
# ...    ...                                ...    ...        ...
# 3628  1999      July 23, 1999 (United States)    7.2     8400.0
# 3629  1999  February 4, 2000 (United Kingdom)    7.6     5500.0
# 3630  1999         September 4, 1999 (France)    7.1     5300.0
# 3632  1999        February 11, 1999 (Germany)    7.2     6200.0
# 3641  1999            March 31, 1999 (France)    7.5    13000.0
#
#                director              writer                star  \
# 0       Stanley Kubrick        Stephen King      Jack Nicholson
# 2        Irvin Kershner      Leigh Brackett         Mark Hamill
# 3          Jim Abrahams        Jim Abrahams         Robert Hays
# 4          Harold Ramis  Brian Doyle-Murray         Chevy Chase
# 6           John Landis         Dan Aykroyd        John Belushi
# ...                 ...                 ...                 ...
# 3628           Jim Fall       Jason Schafer  Christian Campbell
# 3629      Shane Meadows         Robyn Slovo   Martin Arrowsmith
# 3630  Frédéric Fonteyne   Philippe Blasband       Nathalie Baye
# 3632     Max Färberböck      Max Färberböck      Maria Schrader
# 3641    Patrice Leconte       Serge Frydman     Vanessa Paradis
#
#              country      budget        gross  \
# 0     United Kingdom  19000000.0   46998772.0
# 2      United States  18000000.0  538375067.0
# 3      United States   3500000.0   83453539.0
# 4      United States   6000000.0   39846344.0
# 6      United States  27000000.0  115229890.0
# ...              ...         ...          ...
# 3628   United States    450000.0    2087228.0
# 3629  United Kingdom         NaN      19478.0
# 3630          France         NaN     401299.0
# 3632         Germany         NaN     927107.0
# 3641          France         NaN          NaN
#
#                                company  runtime
# 0                         Warner Bros.    146.0
# 2                            Lucasfilm    124.0
# 3                   Paramount Pictures     88.0
# 4                       Orion Pictures     98.0
# 6                   Universal Pictures    133.0
# ...                                ...      ...
# 3628                      Good Machine     89.0
# 3629  Alliance Atlantis Communications     90.0
# 3630               Artémis Productions     80.0
# 3632           Senator Film Produktion    125.0
# 3641                            Canal+     90.0
#
# [969 rows x 15 columns]
